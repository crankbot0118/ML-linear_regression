# %%
# finaldata.csv is uploaded using pandas

# %%
import pandas as pd
data=pd.read_csv("finaldata.csv")
data
# Out:
#     year    ap  arp   ass   bih   chh  goa  guj   har   hp  ...   utt  utk  \
# 0   2001   871   33   817   888   959   12  286   398  124  ...  1958   74
# 1   2002  1002   38   970  1040   992   12  267   361  137  ...  1415   89
# 2   2003   946   31  1095   985   898   31  236   353  126  ...   911  107
# 3   2004  1016   42  1171  1390   969   37  339   386  153  ...  1397  115
# 4   2005   935   35  1238  1147   990   20  324   461  141  ...  1217  133
# 5   2006  1049   37  1244  1232   995   21  354   608  113  ...  1314  147
# 6   2007  1070   48  1437  1555   982   20  316   488  159  ...  1648  117
# 7   2008  1257   42  1438  1302   978   30  374   631  157  ...  1871   87
# 8   2009  1188   59  1631   929   976   47  433   603  183  ...  1759  111
# 9   2010  1362   47  1721   795  1012   36  408   720  160  ...  1563  121
# 10  2011  1442   42  1700   934  1053   29  439   733  168  ...  2042  129
# ...

# %%
#plotting the data

# %%
from matplotlib import pyplot as plt1
from matplotlib import pyplot as plt2
from matplotlib import pyplot as plt3
from matplotlib import pyplot as plt4
from matplotlib import pyplot as plt5
from matplotlib import pyplot as plt6
from matplotlib import pyplot as plt7
from matplotlib import pyplot as plt8
from matplotlib import pyplot as plt9
from matplotlib import pyplot as plt10
from matplotlib import pyplot as plt11
from matplotlib import pyplot as plt12
from matplotlib import pyplot as plt13
from matplotlib import pyplot as plt14
from matplotlib import pyplot as plt15
from matplotlib import pyplot as plt16
from matplotlib import pyplot as plt17
from matplotlib import pyplot as plt18
from matplotlib import pyplot as plt19
from matplotlib import pyplot as plt20
from matplotlib import pyplot as plt21
from matplotlib import pyplot as plt22
from matplotlib import pyplot as plt23
from matplotlib import pyplot as plt24
from matplotlib import pyplot as plt25
from matplotlib import pyplot as plt26
from matplotlib import pyplot as plt27
from matplotlib import pyplot as plt28
from matplotlib import pyplot as plt29
from matplotlib import pyplot as plt30
from matplotlib import pyplot as plt31
from matplotlib import pyplot as plt32
from matplotlib import pyplot as plt33
from matplotlib import pyplot as plt34
from matplotlib import pyplot as plt35
from matplotlib import pyplot as plt36
# %matplotlib inline


#andhrapradesh-------------------------------------------------------------------------------------------
plt1.rcParams["figure.figsize"] = (8, 4)
plt1.xlim(2001,2020)
plt1.ylim(0,6000)

plt1.scatter(data.year,data.ap,color="black")
plt1.plot(data.year,data.ap,color="violet")
plt1.grid()
plt1.show()

#arunachal pradesh-------------------------------------------------------------------------------------------
plt2.rcParams["figure.figsize"] = (8, 4)
plt2.xlim(2001,2020)
plt2.ylim(0,100)

plt2.scatter(data.year,data.arp,color="black")
plt2.plot(data.year,data.arp,color="red")
plt2.grid()
plt2.show()

#assam-------------------------------------------------------------------------------------------
plt3.rcParams["figure.figsize"] = (8, 4)
plt3.xlim(2001,2020)
plt3.ylim(0,3000)

plt3.scatter(data.year,data.ass,color="black")
plt3.plot(data.year,data.ass,color="green")
plt3.grid()
plt3.show()

#bihar-------------------------------------------------------------------------------------------
plt4.rcParams["figure.figsize"] = (8, 4)
plt4.xlim(2001,2020)
plt4.ylim(0,2000)

plt4.scatter(data.year,data.bih,color="black")
plt4.plot(data.year,data.bih,color="red")
plt4.grid()
plt4.show()

#chhatisgarh-------------------------------------------------------------------------------------------
plt5.rcParams["figure.figsize"] = (8, 4)
plt5.xlim(2001,2020)
plt5.ylim(0,2000)

plt5.scatter(data.year,data.chh,color="black")
plt5.plot(data.year,data.chh,color="pink")
plt5.grid()
plt5.show()

#goa-------------------------------------------------------------------------------------------
plt6.rcParams["figure.figsize"] = (8, 4)
plt6.xlim(2001,2020)
plt6.ylim(0,100)

plt6.scatter(data.year,data.goa,color="black")
plt6.plot(data.year,data.goa,color="brown")
plt6.grid()
plt6.show()

#gujarat-------------------------------------------------------------------------------------------
plt7.rcParams["figure.figsize"] = (8, 4)
plt7.xlim(2001,2020)
plt7.ylim(0,1000)

plt7.scatter(data.year,data.guj,color="black")
plt7.plot(data.year,data.guj,color="yellow")
plt7.grid()
plt7.show()

#haryana-------------------------------------------------------------------------------------------
plt8.rcParams["figure.figsize"] = (8, 4)
plt8.xlim(2001,2020)
plt8.ylim(0,2000)

plt8.scatter(data.year,data.har,color="black")
plt8.plot(data.year,data.har,color="orange")
plt8.grid()
plt8.show()

#himachal pradesh-------------------------------------------------------------------------------------------
plt10.rcParams["figure.figsize"] = (8, 4)
plt10.xlim(2001,2020)
plt10.ylim(0,300)

plt10.scatter(data.year,data.hp,color="black")
plt10.plot(data.year,data.hp,color="brown")
plt10.grid()
plt10.show()

#jammu and kashmir-------------------------------------------------------------------------------------------
plt11.rcParams["figure.figsize"] = (8, 4)
plt11.xlim(2001,2020)
plt11.ylim(0,500)

plt11.scatter(data.year,data.jk,color="black")
plt11.plot(data.year,data.jk,color="yellow")
plt11.grid()
plt11.show()

#jharkand-------------------------------------------------------------------------------------------
plt12.rcParams["figure.figsize"] = (8, 4)
plt12.xlim(2001,2020)
plt12.ylim(0,1500)

plt12.scatter(data.year,data.jha,color="black")
plt12.plot(data.year,data.jha,color="red")
plt12.grid()
plt12.show()

#karnataka-------------------------------------------------------------------------------------------
plt13.rcParams["figure.figsize"] = (8, 4)
plt13.xlim(2001,2020)
plt13.ylim(0,3000)

plt13.scatter(data.year,data.kar,color="black")
plt13.plot(data.year,data.kar,color="green")
plt13.grid()
plt13.show()

#kerala-------------------------------------------------------------------------------------------
plt14.rcParams["figure.figsize"] = (8, 4)
plt14.xlim(2001,2020)
plt14.ylim(0,3000)

plt14.scatter(data.year,data.ker,color="black")
plt14.plot(data.year,data.ker,color="orange")
plt14.grid()
plt14.show()

#madhya pradesh-------------------------------------------------------------------------------------------
plt15.rcParams["figure.figsize"] = (8, 4)
plt15.xlim(2001,2020)
plt15.ylim(0,6000)

plt15.scatter(data.year,data.mp,color="black")
plt15.plot(data.year,data.mp,color="brown")
plt15.grid()
plt15.show()

#maharashtra-------------------------------------------------------------------------------------------
plt16.rcParams["figure.figsize"] = (8, 4)
plt16.xlim(2001,2020)
plt16.ylim(0,6000)

plt16.scatter(data.year,data.mh,color="black")
plt16.plot(data.year,data.mh,color="red")
plt16.grid()
plt16.show()

#manipur-------------------------------------------------------------------------------------------
plt17.rcParams["figure.figsize"] = (8, 4)
plt17.xlim(2001,2020)
plt17.ylim(0,100)

plt17.scatter(data.year,data.man,color="black")
plt17.plot(data.year,data.man,color="pink")
plt17.grid()
plt17.show()

#meghalaya-------------------------------------------------------------------------------------------
plt18.rcParams["figure.figsize"] = (8, 4)
plt18.xlim(2001,2020)
plt18.ylim(0,200)

plt18.scatter(data.year,data.meg,color="black")
plt18.plot(data.year,data.meg,color="violet")
plt18.grid()
plt18.show()

#mizoram-------------------------------------------------------------------------------------------
plt19.rcParams["figure.figsize"] = (8, 4)
plt19.xlim(2001,2020)
plt19.ylim(0,200)

plt19.scatter(data.year,data.miz,color="black")
plt19.plot(data.year,data.miz,color="green")
plt19.grid()
plt19.show()

#nagaland-------------------------------------------------------------------------------------------
plt9.rcParams["figure.figsize"] = (8, 4)
plt9.xlim(2001,2020)
plt9.ylim(0,100)

plt9.scatter(data.year,data.nag,color="black")
plt9.plot(data.year,data.nag,color="green")
plt9.grid()
plt9.show()

#odisha-------------------------------------------------------------------------------------------
plt20.rcParams["figure.figsize"] = (8, 4)
plt20.xlim(2001,2020)
plt20.ylim(0,3000)

plt20.scatter(data.year,data.odi,color="black")
plt20.plot(data.year,data.odi,color="brown")
plt20.grid()
plt20.show()

#punjab-------------------------------------------------------------------------------------------
plt21.rcParams["figure.figsize"] = (8, 4)
plt21.xlim(2001,2020)
plt21.ylim(0,2000)

plt21.scatter(data.year,data.pun,color="black")
plt21.plot(data.year,data.pun,color="orange")
plt21.grid()
plt21.show()

#rajasthan-------------------------------------------------------------------------------------------
plt22.rcParams["figure.figsize"] = (8, 4)
plt22.xlim(2001,2020)
plt22.ylim(0,4000)

plt22.scatter(data.year,data.raj,color="black")
plt22.plot(data.year,data.raj,color="violet")
plt22.grid()
plt22.show()

#sikkim-------------------------------------------------------------------------------------------
plt23.rcParams["figure.figsize"] = (8, 4)
plt23.xlim(2001,2020)
plt23.ylim(0,100)

plt23.scatter(data.year,data.sik,color="black")
plt23.plot(data.year,data.sik,color="red")
plt23.grid()
plt23.show()

#tamilnadu-------------------------------------------------------------------------------------------
plt24.rcParams["figure.figsize"] = (8, 4)
plt24.xlim(2001,2020)
plt24.ylim(0,1000)

plt24.scatter(data.year,data.tam,color="black")
plt24.plot(data.year,data.tam,color="green")
plt24.grid()
plt24.show()

#telangana-------------------------------------------------------------------------------------------
plt25.rcParams["figure.figsize"] = (8, 4)
plt25.xlim(2001,2020)
plt25.ylim(0,2000)

plt25.scatter(data.year,data.tel,color="black")
plt25.plot(data.year,data.tel,color="red")
plt25.grid()
plt25.show()

#tripura-------------------------------------------------------------------------------------------
plt26.rcParams["figure.figsize"] = (8, 4)
plt26.xlim(2001,2020)
plt26.ylim(0,1000)

plt26.scatter(data.year,data.tri,color="black")
plt26.plot(data.year,data.tri,color="pink")
plt26.grid()
plt26.show()

#uttar pradesh-------------------------------------------------------------------------------------------
plt27.rcParams["figure.figsize"] = (8, 4)
plt27.xlim(2001,2020)
plt27.ylim(0,4000)

plt27.scatter(data.year,data.utt,color="black")
plt27.plot(data.year,data.utt,color="orange")
plt27.grid()
plt27.show()

#uttarakhand-------------------------------------------------------------------------------------------
plt28.rcParams["figure.figsize"] = (8, 4)
plt28.xlim(2001,2020)
plt28.ylim(0,500)

plt28.scatter(data.year,data.utk,color="black")
plt28.plot(data.year,data.utk,color="brown")
plt28.grid()
plt28.show()

#westbengal-------------------------------------------------------------------------------------------
plt29.rcParams["figure.figsize"] = (8, 4)
plt29.xlim(2001,2020)
plt29.ylim(0,3000)

plt29.scatter(data.year,data.wb,color="black")
plt29.plot(data.year,data.wb,color="green")
plt29.grid()
plt29.show()

#andaman and nicobar islands-------------------------------------------------------------------------------------------
plt30.rcParams["figure.figsize"] = (8, 4)
plt30.xlim(2001,2020)
plt30.ylim(0,100)

plt30.scatter(data.year,data.an,color="black")
plt30.plot(data.year,data.an,color="pink")
plt30.grid()
plt30.show()

#chandigarh-------------------------------------------------------------------------------------------
plt31.rcParams["figure.figsize"] = (8, 4)
plt31.xlim(2001,2020)
plt31.ylim(0,100)

plt31.scatter(data.year,data.chan,color="black")
plt31.plot(data.year,data.chan,color="red")
plt31.grid()
plt31.show()

#dadar and nagar haveli-------------------------------------------------------------------------------------------
plt32.rcParams["figure.figsize"] = (8, 4)
plt32.xlim(2001,2020)
plt32.ylim(0,100)

plt32.scatter(data.year,data.dn,color="black")
plt32.plot(data.year,data.dn,color="violet")
plt32.grid()
plt32.show()

#daman and diu-------------------------------------------------------------------------------------------
plt33.rcParams["figure.figsize"] = (8, 4)
plt33.xlim(2001,2020)
plt33.ylim(0,100)

plt33.scatter(data.year,data.dd,color="black")
plt33.plot(data.year,data.dd,color="orange")
plt33.grid()
plt33.show()

#delhi-------------------------------------------------------------------------------------------
plt34.rcParams["figure.figsize"] = (8, 4)
plt34.xlim(2001,2020)
plt34.ylim(0,3000)

plt34.scatter(data.year,data.delhi,color="black")
plt34.plot(data.year,data.delhi,color="violet")
plt34.grid()
plt34.show()

#lakshadweep-------------------------------------------------------------------------------------------
plt35.rcParams["figure.figsize"] = (8, 4)
plt35.xlim(2001,2020)
plt35.ylim(0,100)

plt35.scatter(data.year,data.lak,color="black")
plt35.plot(data.year,data.lak,color="orange")
plt35.grid()
plt35.show()

#puducherry-------------------------------------------------------------------------------------------
plt36.rcParams["figure.figsize"] = (8, 4)
plt36.xlim(2001,2020)
plt36.ylim(0,100)

plt36.scatter(data.year,data.pud,color="black")
plt36.plot(data.year,data.pud,color="pink")
plt36.grid()
plt36.show()

# %%
#import linear regression model

# %%
from sklearn import linear_model
model1=linear_model.LinearRegression()
model2=linear_model.LinearRegression()
model3=linear_model.LinearRegression()
model4=linear_model.LinearRegression()
model5=linear_model.LinearRegression()
model6=linear_model.LinearRegression()
model7=linear_model.LinearRegression()
model8=linear_model.LinearRegression()
model9=linear_model.LinearRegression()
model10=linear_model.LinearRegression()
model11=linear_model.LinearRegression()
model12=linear_model.LinearRegression()
model13=linear_model.LinearRegression()
model14=linear_model.LinearRegression()
model15=linear_model.LinearRegression()
model16=linear_model.LinearRegression()
model17=linear_model.LinearRegression()
model18=linear_model.LinearRegression()
model19=linear_model.LinearRegression()
model20=linear_model.LinearRegression()
model21=linear_model.LinearRegression()
model22=linear_model.LinearRegression()
model23=linear_model.LinearRegression()
model24=linear_model.LinearRegression()
model25=linear_model.LinearRegression()
model26=linear_model.LinearRegression()
model27=linear_model.LinearRegression()
model28=linear_model.LinearRegression()
model29=linear_model.LinearRegression()
model30=linear_model.LinearRegression()
model31=linear_model.LinearRegression()
model32=linear_model.LinearRegression()
model33=linear_model.LinearRegression()
model34=linear_model.LinearRegression()
model35=linear_model.LinearRegression()
model36=linear_model.LinearRegression()


model1.fit(data[["year"]],data.ap)
model2.fit(data[["year"]],data.arp)
model3.fit(data[["year"]],data.ass)
model4.fit(data[["year"]],data.bih)
model5.fit(data[["year"]],data.chh)
model6.fit(data[["year"]],data.goa)
model7.fit(data[["year"]],data.guj)
model8.fit(data[["year"]],data.har)
model10.fit(data[["year"]],data.hp)
model11.fit(data[["year"]],data.jk)
model12.fit(data[["year"]],data.jha)
model13.fit(data[["year"]],data.kar)
model14.fit(data[["year"]],data.ker)
model15.fit(data[["year"]],data.mp)
model16.fit(data[["year"]],data.mh)
model17.fit(data[["year"]],data.man)
model18.fit(data[["year"]],data.meg)
model19.fit(data[["year"]],data.miz)
model9.fit(data[["year"]],data.nag)
model20.fit(data[["year"]],data.odi)
model21.fit(data[["year"]],data.pun)
model22.fit(data[["year"]],data.raj)
model23.fit(data[["year"]],data.sik)
model24.fit(data[["year"]],data.tam)
model25.fit(data[["year"]],data.tel)
model26.fit(data[["year"]],data.tri)
model27.fit(data[["year"]],data.utt)
model28.fit(data[["year"]],data.utk)
model29.fit(data[["year"]],data.wb)
model30.fit(data[["year"]],data.an)
model31.fit(data[["year"]],data.chan)
model32.fit(data[["year"]],data.dn)
model33.fit(data[["year"]],data.dd)
model34.fit(data[["year"]],data.delhi)
model35.fit(data[["year"]],data.lak)
model36.fit(data[["year"]],data.pud)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#test
model1.predict([[2017]])
# Out:
# array([1296.5])

# %%
from matplotlib import pyplot as plt1
from matplotlib import pyplot as plt2
from matplotlib import pyplot as plt3
from matplotlib import pyplot as plt4
from matplotlib import pyplot as plt5
from matplotlib import pyplot as plt6
from matplotlib import pyplot as plt7
from matplotlib import pyplot as plt8
from matplotlib import pyplot as plt9
from matplotlib import pyplot as plt10
from matplotlib import pyplot as plt11
from matplotlib import pyplot as plt12
from matplotlib import pyplot as plt13
from matplotlib import pyplot as plt14
from matplotlib import pyplot as plt15
from matplotlib import pyplot as plt16
from matplotlib import pyplot as plt17
from matplotlib import pyplot as plt18
from matplotlib import pyplot as plt19
from matplotlib import pyplot as plt20
from matplotlib import pyplot as plt21
from matplotlib import pyplot as plt22
from matplotlib import pyplot as plt23
from matplotlib import pyplot as plt24
from matplotlib import pyplot as plt25
from matplotlib import pyplot as plt26
from matplotlib import pyplot as plt27
from matplotlib import pyplot as plt28
from matplotlib import pyplot as plt29
from matplotlib import pyplot as plt30
from matplotlib import pyplot as plt31
from matplotlib import pyplot as plt32
from matplotlib import pyplot as plt33
from matplotlib import pyplot as plt34
from matplotlib import pyplot as plt35
from matplotlib import pyplot as plt36
# %matplotlib inline



plt1.rcParams["figure.figsize"] = (8, 4)
plt1.xlim(2001,2020)
plt1.ylim(0,6000)

plt1.scatter(data.year,data.ap,color="black")
plt1.scatter(data.year,model1.predict(data[["year"]]))
plt1.plot(data.year,data.ap,color="violet")
plt1.plot(data.year,model1.predict(data[["year"]]))
plt1.grid()
plt1.show()



plt2.rcParams["figure.figsize"] = (8, 4)
plt2.xlim(2001,2020)
plt2.ylim(0,100)

plt2.scatter(data.year,data.arp,color="black")
plt2.scatter(data.year,model2.predict(data[["year"]]))
plt2.plot(data.year,data.arp,color="red")
plt2.plot(data.year,model2.predict(data[["year"]]))
plt2.grid()
plt2.show()



plt3.rcParams["figure.figsize"] = (8, 4)
plt3.xlim(2001,2020)
plt3.ylim(0,3000)

plt3.scatter(data.year,data.ass,color="black")
plt3.scatter(data.year,model3.predict(data[["year"]]))
plt3.plot(data.year,data.ass,color="green")
plt3.plot(data.year,model3.predict(data[["year"]]))
plt3.grid()
plt3.show()



plt4.rcParams["figure.figsize"] = (8, 4)
plt4.xlim(2001,2020)
plt4.ylim(0,2000)

plt4.scatter(data.year,data.bih,color="black")
plt4.scatter(data.year,model4.predict(data[["year"]]))
plt4.plot(data.year,data.bih,color="red")
plt4.plot(data.year,model4.predict(data[["year"]]))
plt4.grid()
plt4.show()



plt5.rcParams["figure.figsize"] = (8, 4)
plt5.xlim(2001,2020)
plt5.ylim(0,2000)

plt5.scatter(data.year,data.chh,color="black")
plt5.scatter(data.year,model5.predict(data[["year"]]))
plt5.plot(data.year,data.chh,color="pink")
plt5.plot(data.year,model5.predict(data[["year"]]))
plt5.grid()

plt5.show()



plt6.rcParams["figure.figsize"] = (8, 4)
plt6.xlim(2001,2020)
plt6.ylim(0,100)

plt6.scatter(data.year,data.goa,color="black")
plt6.scatter(data.year,model6.predict(data[["year"]]))
plt6.plot(data.year,data.goa,color="brown")
plt6.plot(data.year,model6.predict(data[["year"]]))
plt6.grid()

plt6.show()



plt7.rcParams["figure.figsize"] = (8, 4)
plt7.xlim(2001,2020)
plt7.ylim(0,1000)

plt7.scatter(data.year,data.guj,color="black")
plt7.scatter(data.year,model7.predict(data[["year"]]))
plt7.plot(data.year,data.guj,color="yellow")
plt7.plot(data.year,model7.predict(data[["year"]]))
plt7.grid()
plt7.show()



plt8.rcParams["figure.figsize"] = (8, 4)
plt8.xlim(2001,2020)
plt8.ylim(0,2000)

plt8.scatter(data.year,data.har,color="black")
plt8.scatter(data.year,model8.predict(data[["year"]]))
plt8.plot(data.year,data.har,color="orange")
plt8.plot(data.year,model8.predict(data[["year"]]))
plt8.grid()
plt8.show()



plt10.rcParams["figure.figsize"] = (8, 4)
plt10.xlim(2001,2020)
plt10.ylim(0,300)

plt10.scatter(data.year,data.hp,color="black")
plt10.scatter(data.year,model10.predict(data[["year"]]))
plt10.plot(data.year,data.hp,color="brown")
plt10.plot(data.year,model10.predict(data[["year"]]))
plt10.grid()
plt10.show()



plt11.rcParams["figure.figsize"] = (8, 4)
plt11.xlim(2001,2020)
plt11.ylim(0,500)

plt11.scatter(data.year,data.jk,color="black")
plt11.scatter(data.year,model11.predict(data[["year"]]))
plt11.plot(data.year,data.jk,color="yellow")
plt11.plot(data.year,model11.predict(data[["year"]]))
plt11.grid()
plt11.show()



plt12.rcParams["figure.figsize"] = (8, 4)
plt12.xlim(2001,2020)
plt12.ylim(0,1500)

plt12.scatter(data.year,data.jha,color="black")
plt12.scatter(data.year,model12.predict(data[["year"]]))
plt12.plot(data.year,data.jha,color="red")
plt12.plot(data.year,model12.predict(data[["year"]]))
plt12.grid()
plt12.show()



plt13.rcParams["figure.figsize"] = (8, 4)
plt13.xlim(2001,2020)
plt13.ylim(0,3000)

plt13.scatter(data.year,data.kar,color="black")
plt13.scatter(data.year,model13.predict(data[["year"]]))
plt13.plot(data.year,data.kar,color="green")
plt13.plot(data.year,model13.predict(data[["year"]]))
plt13.grid()
plt13.show()



plt14.rcParams["figure.figsize"] = (8, 4)
plt14.xlim(2001,2020)
plt14.ylim(0,3000)

plt14.scatter(data.year,data.ker,color="black")
plt14.scatter(data.year,model14.predict(data[["year"]]))
plt14.plot(data.year,data.ker,color="orange")
plt14.plot(data.year,model14.predict(data[["year"]]))
plt14.grid()
plt14.show()



plt15.rcParams["figure.figsize"] = (8, 4)
plt15.xlim(2001,2020)
plt15.ylim(0,6000)

plt15.scatter(data.year,data.mp,color="black")
plt15.scatter(data.year,model15.predict(data[["year"]]))
plt15.plot(data.year,data.mp,color="brown")
plt15.plot(data.year,model15.predict(data[["year"]]))
plt15.grid()
plt15.show()



plt16.rcParams["figure.figsize"] = (8, 4)
plt16.xlim(2001,2020)
plt16.ylim(0,6000)

plt16.scatter(data.year,data.mh,color="black")
plt16.scatter(data.year,model16.predict(data[["year"]]))
plt16.plot(data.year,data.mh,color="red")
plt16.plot(data.year,model16.predict(data[["year"]]))
plt16.grid()
plt16.show()



plt17.rcParams["figure.figsize"] = (8, 4)
plt17.xlim(2001,2020)
plt17.ylim(0,100)

plt17.scatter(data.year,data.man,color="black")
plt17.scatter(data.year,model17.predict(data[["year"]]))
plt17.plot(data.year,data.man,color="pink")
plt17.plot(data.year,model17.predict(data[["year"]]))
plt17.grid()
plt17.show()



plt18.rcParams["figure.figsize"] = (8, 4)
plt18.xlim(2001,2020)
plt18.ylim(0,200)

plt18.scatter(data.year,data.meg,color="black")
plt18.scatter(data.year,model18.predict(data[["year"]]))
plt18.plot(data.year,data.meg,color="violet")
plt18.plot(data.year,model18.predict(data[["year"]]))
plt18.grid()
plt18.show()

plt19.rcParams["figure.figsize"] = (8, 4)
plt19.xlim(2001,2020)
plt19.ylim(0,200)

plt19.scatter(data.year,data.miz,color="black")
plt19.scatter(data.year,model19.predict(data[["year"]]))
plt19.plot(data.year,data.miz,color="green")
plt19.plot(data.year,model19.predict(data[["year"]]))
plt19.grid()
plt19.show()


plt9.rcParams["figure.figsize"] = (8, 4)
plt9.xlim(2001,2020)
plt9.ylim(0,100)

plt9.scatter(data.year,data.nag,color="black")
plt9.scatter(data.year,model9.predict(data[["year"]]))
plt9.plot(data.year,data.nag,color="green")
plt9.plot(data.year,model9.predict(data[["year"]]))
plt9.grid()
plt9.show()



plt20.rcParams["figure.figsize"] = (8, 4)
plt20.xlim(2001,2020)
plt20.ylim(0,3000)

plt20.scatter(data.year,data.odi,color="black")
plt20.scatter(data.year,model20.predict(data[["year"]]))
plt20.plot(data.year,data.odi,color="brown")
plt20.plot(data.year,model20.predict(data[["year"]]))
plt20.grid()
plt20.show()



plt21.rcParams["figure.figsize"] = (8, 4)
plt21.xlim(2001,2020)
plt21.ylim(0,2000)

plt21.scatter(data.year,data.pun,color="black")
plt21.scatter(data.year,model21.predict(data[["year"]]))
plt21.plot(data.year,data.pun,color="orange")
plt21.plot(data.year,model21.predict(data[["year"]]))
plt21.grid()
plt21.show()



plt22.rcParams["figure.figsize"] = (8, 4)
plt22.xlim(2001,2020)
plt22.ylim(0,4000)

plt22.scatter(data.year,data.raj,color="black")
plt22.scatter(data.year,model22.predict(data[["year"]]))
plt22.plot(data.year,data.raj,color="violet")
plt22.plot(data.year,model22.predict(data[["year"]]))
plt22.grid()
plt22.show()



plt23.rcParams["figure.figsize"] = (8, 4)
plt23.xlim(2001,2020)
plt23.ylim(0,100)

plt23.scatter(data.year,data.sik,color="black")
plt23.scatter(data.year,model23.predict(data[["year"]]))
plt23.plot(data.year,data.sik,color="red")
plt23.plot(data.year,model23.predict(data[["year"]]))
plt23.grid()
plt23.show()



plt24.rcParams["figure.figsize"] = (8, 4)
plt24.xlim(2001,2020)
plt24.ylim(0,1000)

plt24.scatter(data.year,data.tam,color="black")
plt24.scatter(data.year,model24.predict(data[["year"]]))
plt24.plot(data.year,data.tam,color="green")
plt24.plot(data.year,model24.predict(data[["year"]]))
plt24.grid()
plt24.show()



plt25.rcParams["figure.figsize"] = (8, 4)
plt25.xlim(2001,2020)
plt25.ylim(0,2000)

plt25.scatter(data.year,data.tel,color="black")
plt25.scatter(data.year,model25.predict(data[["year"]]))
plt25.plot(data.year,data.tel,color="red")
plt25.plot(data.year,model25.predict(data[["year"]]))
plt25.grid()
plt25.show()



plt26.rcParams["figure.figsize"] = (8, 4)
plt26.xlim(2001,2020)
plt26.ylim(0,1000)

plt26.scatter(data.year,data.tri,color="black")
plt26.scatter(data.year,model26.predict(data[["year"]]))
plt26.plot(data.year,data.tri,color="pink")
plt26.plot(data.year,model26.predict(data[["year"]]))
plt26.grid()
plt26.show()



plt27.rcParams["figure.figsize"] = (8, 4)
plt27.xlim(2001,2020)
plt27.ylim(0,4000)

plt27.scatter(data.year,data.utt,color="black")
plt27.scatter(data.year,model27.predict(data[["year"]]))
plt27.plot(data.year,data.utt,color="orange")
plt27.plot(data.year,model27.predict(data[["year"]]))
plt27.grid()
plt27.show()



plt28.rcParams["figure.figsize"] = (8, 4)
plt28.xlim(2001,2020)
plt28.ylim(0,500)

plt28.scatter(data.year,data.utk,color="black")
plt28.scatter(data.year,model28.predict(data[["year"]]))
plt28.plot(data.year,data.utk,color="brown")
plt28.plot(data.year,model28.predict(data[["year"]]))
plt28.grid()
plt28.show()



plt29.rcParams["figure.figsize"] = (8, 4)
plt29.xlim(2001,2020)
plt29.ylim(0,3000)

plt29.scatter(data.year,data.wb,color="black")
plt29.scatter(data.year,model29.predict(data[["year"]]))
plt29.plot(data.year,data.wb,color="green")
plt29.plot(data.year,model29.predict(data[["year"]]))
plt29.grid()
plt29.show()



plt30.rcParams["figure.figsize"] = (8, 4)
plt30.xlim(2001,2020)
plt30.ylim(0,100)

plt30.scatter(data.year,data.an,color="black")
plt30.scatter(data.year,model30.predict(data[["year"]]))
plt30.plot(data.year,data.an,color="pink")
plt30.plot(data.year,model30.predict(data[["year"]]))
plt30.grid()
plt30.show()



plt31.rcParams["figure.figsize"] = (8, 4)
plt31.xlim(2001,2020)
plt31.ylim(0,100)

plt31.scatter(data.year,data.chan,color="black")
plt31.scatter(data.year,model31.predict(data[["year"]]))
plt31.plot(data.year,data.chan,color="red")
plt31.plot(data.year,model31.predict(data[["year"]]))
plt31.grid()
plt31.show()



plt32.rcParams["figure.figsize"] = (8, 4)
plt32.xlim(2001,2020)
plt32.ylim(0,100)

plt32.scatter(data.year,data.dn,color="black")
plt32.scatter(data.year,model32.predict(data[["year"]]))
plt32.plot(data.year,data.dn,color="violet")
plt32.plot(data.year,model32.predict(data[["year"]]))
plt32.grid()
plt32.show()


plt33.rcParams["figure.figsize"] = (8, 4)
plt33.xlim(2001,2020)
plt33.ylim(0,100)

plt33.scatter(data.year,data.dd,color="black")
plt33.scatter(data.year,model33.predict(data[["year"]]))
plt33.plot(data.year,data.dd,color="orange")
plt33.plot(data.year,model33.predict(data[["year"]]))
plt33.grid()
plt33.show()



plt34.rcParams["figure.figsize"] = (8, 4)
plt34.xlim(2001,2020)
plt34.ylim(0,3000)

plt34.scatter(data.year,data.delhi,color="black")
plt34.scatter(data.year,model34.predict(data[["year"]]))
plt34.plot(data.year,data.delhi,color="violet")
plt34.plot(data.year,model34.predict(data[["year"]]))
plt34.grid()
plt34.show()



plt35.rcParams["figure.figsize"] = (8, 4)
plt35.xlim(2001,2020)
plt35.ylim(0,100)

plt35.scatter(data.year,data.lak,color="black")
plt35.scatter(data.year,model35.predict(data[["year"]]))
plt35.plot(data.year,data.lak,color="orange")
plt35.plot(data.year,model35.predict(data[["year"]]))
plt35.grid()
plt35.show()





plt36.rcParams["figure.figsize"] = (8, 4)
plt36.xlim(2001,2020)
plt36.ylim(0,100)

plt36.scatter(data.year,data.pud,color="black")
plt36.scatter(data.year,model36.predict(data[["year"]]))
plt36.plot(data.year,data.pud,color="pink")
plt36.plot(data.year,model36.predict(data[["year"]]))
plt36.grid()
plt36.show()

# %%
model.score(data[["year"]],data.ap)
# Out:
# 0.13590913391881942
